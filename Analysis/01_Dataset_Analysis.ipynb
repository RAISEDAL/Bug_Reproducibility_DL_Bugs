# %%
import pandas as pd
import re
from collections import Counter

# %%
keras = pd.read_csv('../Dataset/Keras_Posts.csv')
tensorflow = pd.read_csv('../Dataset/Tensorflow_Posts.csv')
pytorch = pd.read_csv('../Dataset/Pytorch_Posts.csv')

# Merge these dataframes
df = pd.concat([keras, tensorflow, pytorch], ignore_index=True)

# %%
# Extract tags and count occurrences
tags = [re.findall(r'<([^>]*)>', tag) for tag in df['Tags']]
tag_counts = Counter([tag for sublist in tags for tag in sublist])

# Sort tag counts in descending order
sorted_counts = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

# Print sorted tag counts
for tag, count in sorted_counts:
    print(f"{tag}: {count}")
# Out:
# python: 4641
# pytorch: 3544
# tensorflow: 2985
# deep-learning: 1059
# machine-learning: 835
# keras: 737
# neural-network: 556
# conv-neural-network: 480
# tensorflow2.0: 476
# python-3.x: 407
# tensor: 391
# numpy: 366
# lstm: 201
# tensorflow-datasets: 191
# huggingface-transformers: 183
# tensorflow-lite: 179
# nlp: 166
# computer-vision: 161
# gpu: 157
# tensorflow.js: 152
# torch: 146
# google-colaboratory: 125
# pytorch-lightning: 116
# object-detection: 112
# pandas: 108
# pytorch-dataloader: 104
# javascript: 98
# loss-function: 97
# bert-language-model: 97
# recurrent-neural-network: 92
# torchvision: 91
# classification: 90
# artificial-intelligence: 82
# image-processing: 79
# dataset: 77
# scikit-learn: 75
# autoencoder: 75
# opencv: 68
# jupyter-notebook: 68
# autograd: 66
# object-detection-api: 64
# android: 64
# c++: 64
# tensorflow-federated: 61
# reinforcement-learning: 60
# arrays: 60
# image: 58
# mnist: 57
# generative-adversarial-network: 56
# anaconda: 54
# onnx: 52
# image-classification: 51
# dataloader: 51
# tf.keras: 49
# google-cloud-platform: 49
# training-data: 49
# tensorboard: 48
# docker: 48
# resnet: 46
# nvidia: 44
# cuda: 43
# conda: 43
# image-segmentation: 42
# transfer-learning: 42
# optimization: 39
# tensorflow-probability: 39
# gradient-descent: 38
# transformer-model: 38
# yolo: 38
# matplotlib: 37
# indexing: 36
# cross-entropy: 36
# tensorflow-serving: 36
# r: 35
# amazon-sagemaker: 34
# node.js: 34
# backpropagation: 33
# dataframe: 32
# linear-regression: 32
# libtorch: 31
# model: 30
# pip: 30
# gradient: 30
# pytorch-geometric: 30
# attention-model: 29
# time-series: 27
# semantic-segmentation: 27
# tpu: 26
# tensorflow-hub: 26
# huggingface-tokenizers: 26
# data-augmentation: 25
# vgg-net: 25
# keras-layer: 25
# loss: 25
# concatenation: 25
# yolov5: 25
# fast-ai: 25
# regression: 24
# embedding: 24
# quantization: 24
# matrix: 23
# data-science: 23
# pre-trained-model: 23
# reshape: 23
# visual-studio-code: 23
# apple-m1: 23
# pycharm: 22
# tfrecord: 22
# huggingface: 22
# convolution: 21
# prediction: 21
# batch-normalization: 21
# federated-learning: 21
# java: 21
# valueerror: 20
# numpy-ndarray: 20
# openai-gym: 20
# word-embedding: 20
# cudnn: 20
# vectorization: 20
# multiprocessing: 19
# metrics: 19
# multiclass-classification: 19
# faster-rcnn: 19
# text-classification: 19
# activation-function: 19
# linux: 19
# matrix-multiplication: 19
# mobilenet: 18
# amazon-web-services: 18
# slice: 18
# tf.data.dataset: 18
# kotlin: 18
# performance: 18
# pickle: 17
# dropout: 17
# dqn: 17
# scipy: 17
# csv: 17
# macos: 17
# tensorflow2.x: 17
# reactjs: 17
# array-broadcasting: 17
# attributeerror: 16
# softmax: 15
# math: 15
# ubuntu: 15
# jax: 15
# automatic-differentiation: 15
# parallel-processing: 15
# linear-algebra: 15
# typeerror: 14
# feature-extraction: 14
# list: 14
# kaggle: 14
# android-studio: 14
# flutter: 14
# react-native: 14
# tfx: 14
# python-imaging-library: 14
# runtime-error: 13
# layer: 13
# mse: 13
# multidimensional-array: 13
# import: 13
# onnxruntime: 13
# gradienttape: 13
# windows: 13
# openvino: 13
# memory: 13
# one-hot-encoding: 12
# out-of-memory: 12
# chatbot: 12
# heroku: 12
# normalization: 12
# flask: 12
# torchtext: 12
# sequential: 11
# multilabel-classification: 11
# validation: 11
# mlp: 11
# confusion-matrix: 11
# word2vec: 11
# predict: 11
# tensorrt: 11
# tensorflow-model-garden: 11
# graph: 11
# distributed-computing: 11
# google-coral: 11
# random: 11
# class: 11
# dimensions: 10
# keras-tuner: 10
# image-recognition: 10
# tokenize: 10
# loops: 10
# sentiment-analysis: 10
# jupyter: 10
# c: 10
# gpt-2: 10
# installation: 10
# cmake: 10
# batchsize: 10
# oop: 10
# detectron: 10
# error-handling: 9
# coreml: 9
# learning-rate: 9
# encoder-decoder: 9
# fastapi: 9
# generator: 9
# siamese-network: 9
# numpy-slicing: 9
# django: 9
# image-augmentation: 9
# tflite: 9
# graph-neural-network: 9
# json: 9
# audio: 9
# gaussian-process: 9
# random-seed: 9
# torchaudio: 9
# efficientnet: 8
# c#: 8
# image-preprocessing: 8
# coremltools: 8
# google-cloud-ml: 8
# google-ai-platform: 8
# html: 8
# python-2.7: 8
# language-model: 8
# dictionary: 8
# for-loop: 8
# stable-baselines: 8
# streamlit: 8
# dart: 8
# raspberry-pi: 8
# nvidia-jetson: 8
# quantization-aware-training: 8
# ragged-tensors: 8
# gated-recurrent-unit: 8
# speech-recognition: 8
# floating-point: 8
# autodiff: 8
# importerror: 8
# github: 8
# torchscript: 8
# allennlp: 8
# max-pooling: 7
# azure: 7
# seq2seq: 7
# input: 7
# shapes: 7
# amazon-ec2: 7
# jupyter-lab: 7
# bazel: 7
# tensorflow1.15: 7
# google-mlkit: 7
# google-cloud-storage: 7
# cpu: 7
# tfjs-node: 7
# data-preprocessing: 7
# fft: 7
# nan: 7
# tf-agent: 7
# apache-beam: 7
# parameters: 7
# google-cloud-vertex-ai: 7
# numpy-einsum: 7
# huggingface-datasets: 7
# gridsearchcv: 6
# mask: 6
# recommendation-engine: 6
# bayesian: 6
# overfitting-underfitting: 6
# probability: 6
# rgb: 6
# types: 6
# weighted: 6
# checkpoint: 6
# conv1d: 6
# function: 6
# padding: 6
# module: 6
# dockerfile: 6
# bounding-box: 6
# multithreading: 6
# ubuntu-20.04: 6
# metal: 6
# angular: 6
# roboflow: 6
# slurm: 6
# image-resizing: 6
# albumentations: 6
# unet-neural-network: 6
# typescript: 6
# distributed: 6
# simpletransformers: 6
# affinetransform: 6
# kubernetes: 6
# compiler-errors: 6
# vector: 6
# filter: 6
# string: 6
# tensorflow-agents: 6
# multi-gpu: 6
# dtype: 6
# python-multiprocessing: 6
# memory-leaks: 6
# derivative: 6
# debugging: 6
# inference: 6
# iterator: 6
# gpytorch: 6
# pipeline: 5
# precision-recall: 5
# ocr: 5
# sgd: 5
# keras-rl: 5
# relu: 5
# hyperparameters: 5
# index-error: 5
# h5py: 5
# cross-validation: 5
# save: 5
# genetic-algorithm: 5
# callback: 5
# encoder: 5
# face-detection: 5
# plot: 5
# perceptron: 5
# early-stopping: 5
# sorting: 5
# gensim: 5
# rasa: 5
# nltk: 5
# arm: 5
# time: 5
# protocol-buffers: 5
# librosa: 5
# ray: 5
# miniconda: 5
# face-recognition: 5
# azure-machine-learning-service: 5
# tensorflowjs-converter: 5
# mediapipe: 5
# ragged: 5
# logistic-regression: 5
# batch-processing: 5
# spacy: 5
# signal-processing: 5
# precision: 5
# label: 5
# segmentation-fault: 5
# gpflow: 5
# tensorflow-data-validation: 5
# named-entity-recognition: 5
# dcgan: 5
# tensorflow-xla: 5
# deeplab: 5
# algorithm: 5
# unsupervised-learning: 5
# amazon-s3: 5
# forecasting: 5
# vision: 5
# mean: 5
# imagenet: 5
# distributed-training: 5
# initialization: 5
# jit: 5
# gnn: 5
# ensemble-learning: 4
# evaluation: 4
# databricks: 4
# visualization: 4
# k-fold: 4
# keyerror: 4
# medical-imaging: 4
# roberta-language-model: 4
# data-visualization: 4
# pyspark: 4
# model-fitting: 4
# reticulate: 4
# google-dl-platform: 4
# ios: 4
# load: 4
# ctc: 4
# face-api: 4
# pyinstaller: 4
# yolov4: 4
# google-cloud-tpu: 4
# file: 4
# esp32: 4
# summary: 4
# warnings: 4
# convergence: 4
# memory-management: 4
# ml.net: 4
# centos: 4
# google-chrome-extension: 4
# runtime: 4
# virtualenv: 4
# edge-tpu: 4
# sparse-matrix: 4
# cosine-similarity: 4
# object: 4
# deconvolution: 4
# normal-distribution: 4
# conditional-statements: 4
# grpc: 4
# fine-tune: 4
# xor: 4
# python-3.8: 4
# custom-training: 4
# gcloud: 4
# nvidia-jetson-nano: 4
# openai-api: 4
# intel: 4
# matrix-indexing: 4
# interpolation: 4
# machine-translation: 4
# if-statement: 4
# matlab: 4
# nvcc: 4
# multiplication: 4
# regularized: 4
# tensorboardx: 4
# sentence-transformers: 4
# fairseq: 4
# networkx: 4
# skorch: 4
# transformation: 4
# torchserve: 4
# flatten: 3
# machine-learning-model: 3
# .net: 3
# cv2: 3
# azure-databricks: 3
# auc: 3
# tkinter: 3
# mean-square-error: 3
# sequence-to-sequence: 3
# swift: 3
# train-test-split: 3
# lambda: 3
# bidirectional: 3
# virtual-machine: 3
# random-forest: 3
# data-generation: 3
# densenet: 3
# summarization: 3
# syntax-error: 3
# data-analysis: 3
# operating-system: 3
# julia: 3
# python-class: 3
# deployment: 3
# roc: 3
# q-learning: 3
# imbalanced-data: 3
# zero-padding: 3
# ubuntu-18.04: 3
# sklearn-pandas: 3
# driver: 3
# python-3.7: 3
# oserror: 3
# sentence-similarity: 3
# rasa-nlu: 3
# docker-compose: 3
# arduino: 3
# video: 3
# uvicorn: 3
# expo: 3
# raspberry-pi4: 3
# npm: 3
# bodypix: 3
# nvidia-docker: 3
# version: 3
# google-cloud-dataflow: 3
# c-api: 3
# statistics: 3
# package: 3
# coco: 3
# eager-execution: 3
# microcontroller: 3
# migration: 3
# data-pipeline: 3
# regex: 3
# pca: 3
# yaml: 3
# numba: 3
# automl: 3
# darknet: 3
# knn: 3
# tf2onnx: 3
# shap: 3
# pruning: 3
# pose-estimation: 3
# cluster-computing: 3
# tensorflow2: 3
# rounding: 3
# self-attention: 3
# asynchronous: 3
# gcc: 3
# gunicorn: 3
# casting: 3
# discord.js: 3
# dask: 3
# type-conversion: 3
# ipu: 3
# gcp-ai-platform-notebook: 3
# visual-c++: 3
# dll: 3
# output: 3
# google-bigquery: 3
# scikit-image: 3
# probability-distribution: 3
# wsl-2: 3
# config: 3
# stylegan: 3
# split: 3
# mobile: 3
# horovod: 3
# broadcast: 3
# customization: 3
# sigmoid: 3
# iteration: 3
# tqdm: 3
# weighted-average: 3
# state-dict: 3
# reproducible-research: 3
# langchain: 3
# u8darts: 3
# complex-numbers: 3
# ddp: 3
# exception: 3
# size: 3
# in-place: 3
# tensordot: 3
# boolean: 3
# iris-dataset: 3
# auto-keras: 2
# functional-api: 2
# spyder: 2
# tesseract: 2
# type-hinting: 2
# wandb: 2
# grid-search: 2
# mlmodel: 2
# hdf5: 2
# imageai: 2
# mat: 2
# speech-to-text: 2
# text-processing: 2
# sequence: 2
# starlette: 2
# lstm-stateful: 2
# opencv-python: 2
# deep-residual-networks: 2
# similarity: 2
# pos-tagger: 2
# plaidml: 2
# video-processing: 2
# scatter-plot: 2
# syntax: 2
# feature-selection: 2
# determinants: 2
# mlflow: 2
# data-manipulation: 2
# suppress-warnings: 2
# argmax: 2
# encoding: 2
# grayscale: 2
# cluster-analysis: 2
# chess: 2
# subclass: 2
# language-translation: 2
# instance: 2
# teachable-machine: 2
# api: 2
# windows-subsystem-for-linux: 2
# theano: 2
# directory: 2
# seaborn: 2
# django-views: 2
# windows-10: 2
# apple-silicon: 2
# server: 2
# bash: 2
# google-cloud-functions: 2
# firebase: 2
# nodes: 2
# electron: 2
# ray-tune: 2
# anaconda3: 2
# lookup: 2
# image-rotation: 2
# ordereddictionary: 2
# glibc: 2
# base64: 2
# centos7: 2
# aar: 2
# danfojs: 2
# multivariate-time-series: 2
# gpgpu: 2
# noise: 2
# illegal-instruction: 2
# taylor-series: 2
# ssim: 2
# cpu-usage: 2
# requirements.txt: 2
# detection: 2
# python-3.6: 2
# ml5.js: 2
# xml: 2
# powershell: 2
# mamba: 2
# web-worker: 2
# axis: 2
# dot-product: 2
# mixture-model: 2
# anomaly-detection: 2
# mozilla-deepspeech: 2
# wav: 2
# tensorflow-c++: 2
# rest: 2
# methods: 2
# serialization: 2
# darkflow: 2
# adversarial-machines: 2
# single-shot-detector: 2
# eigenvalue: 2
# eigenvector: 2
# rllib: 2
# google-cloud-automl: 2
# tensorly: 2
# exponential: 2
# opencv3.0: 2
# intel-mkl: 2
# webgl: 2
# google-earth-engine: 2
# elmo: 2
# flatbuffers: 2
# google-codelab: 2
# opennmt: 2
# makefile: 2
# yocto: 2
# object-recognition: 2
# ssh: 2
# profiler: 2
# ode: 2
# command-line: 2
# svm: 2
# text: 2
# variables: 2
# terminal: 2
# resuming-training: 2
# joblib: 2
# mini-forge: 2
# google-chrome: 2
# google-cloud-ai: 2
# bigdata: 2
# bayesian-deep-learning: 2
# tensorflow-estimator: 2
# firebase-machine-learning: 2
# roberta: 2
# tensorflow-transform: 2
# rust: 2
# dimensionality-reduction: 2
# android-ndk: 2
# nginx: 2
# sampling: 2
# resize: 2
# nnapi: 2
# intel-lpot: 2
# python-import: 2
# shuffle: 2
# serving: 2
# aws-lambda: 2
# tensorflow-io: 2
# visual-studio: 2
# std: 2
# multinomial: 2
# gaussian: 2
# gru: 2
# scalar: 2
# deterministic: 2
# computation-graph: 2
# amd: 2
# celery: 2
# binary-matrix: 2
# easyocr: 2
# testing: 2
# tuples: 2
# view: 2
# apex: 2
# logging: 2
# variance: 2
# python-requests: 2
# comparison: 2
# virtual-environment: 2
# distribution: 2
# normalize: 2
# iterable: 2
# retinanet: 2
# mini-batch: 2
# c++11: 2
# storage: 2
# pytorch-distributions: 2
# sockets: 2
# naming-conventions: 2
# stride: 2
# stable-diffusion: 2
# pixel: 2
# forward: 2
# arcface: 2
# dice: 2
# geometry: 2
# mathematical-optimization: 2
# pytorch3d: 2
# higher: 2
# transform: 2
# inheritance: 2
# zarr: 2
# stochastic-gradient: 2
# image-size: 2
# pyro: 2
# distance: 2
# self: 2
# histogram: 2
# dimension: 2
# intel-pytorch: 2
# bilstm: 2
# dynamic-programming: 2
# multi-index: 2
# meta-learning: 2
# matmul: 2
# optuna: 2
# hook: 2
# cupy: 2
# hessian-matrix: 2
# pytorch-forecasting: 2
# einops: 2
# adaptive-threshold: 1
# image-generation: 1
# online-machine-learning: 1
# python-tesseract: 1
# pool: 1
# weak-references: 1
# subplot: 1
# modulenotfounderror: 1
# azure-blob-storage: 1
# masking: 1
# multiple-input: 1
# channel: 1
# style-transfer: 1
# temporal: 1
# coefficients: 1
# trainingloss: 1
# custom-object: 1
# momentum: 1
# missing-data: 1
# byte: 1
# handwriting-recognition: 1
# cjk: 1
# multipleoutputs: 1
# multi-layer: 1
# rescale: 1
# dashboard: 1
# plotly-dash: 1
# decoder: 1
# euclidean-distance: 1
# pad: 1
# mlxtend: 1
# neptune: 1
# zero: 1
# initializer: 1
# rstudio: 1
# chemistry: 1
# unzip: 1
# rfe: 1
# stringtokenizer: 1
# txt: 1
# cimg: 1
# inf: 1
# date: 1
# embedded: 1
# service: 1
# suppressmessage: 1
# flux.jl: 1
# epoch: 1
# dplyr: 1
# imagedatagenerator: 1
# voice-recognition: 1
# evaluate: 1
# standardized: 1
# data-cleaning: 1
# format: 1
# policy-gradient-descent: 1
# distutils: 1
# pylint: 1
# pylance: 1
# gradle: 1
# configuration: 1
# blas: 1
# ngrok: 1
# heatmap: 1
# labelimg: 1
# google-oauth: 1
# metadata: 1
# adb: 1
# low-level: 1
# apt: 1
# augmented-reality: 1
# image-manipulation: 1
# lib: 1
# terraform: 1
# amazon-rds: 1
# amazon-aurora: 1
# g++: 1
# embedded-linux: 1
# dependencies: 1
# excel: 1
# startup: 1
# rtx: 1
# proto: 1
# protobuf-python: 1
# annotations: 1
# patch: 1
# macbookpro-touch-bar: 1
# avx: 1
# pydicom: 1
# tcmalloc: 1
# alpine-linux: 1
# webpack: 1
# tritonserver: 1
# blenderbot: 1
# dataformat: 1
# environment: 1
# firefox-addon: 1
# hashtable: 1
# google-meet: 1
# character-encoding: 1
# instructions: 1
# collections: 1
# protoc: 1
# xserver: 1
# triplestore: 1
# categories: 1
# map-function: 1
# mp3: 1
# arm64: 1
# build.gradle: 1
# z-index: 1
# tiff: 1
# imx6: 1
# imblearn: 1
# smote: 1
# react-hooks: 1
# html5-canvas: 1
# hidden-markov-models: 1
# python-3.9: 1
# deepface: 1
# ubuntu-22.04: 1
# arduino-nano: 1
# nonlinear-functions: 1
# gesture: 1
# bytebuffer: 1
# architecture: 1
# ml-agent: 1
# large-data: 1
# triangular: 1
# concurrent.futures: 1
# google-cloud-vision: 1
# python.net: 1
# ldd: 1
# nlg: 1
# qualcomm: 1
# snpe: 1
# autocomplete: 1
# code-completion: 1
# tensorflow-model-analysis: 1
# ranking: 1
# cielab: 1
# fasttext: 1
# exit-code: 1
# webassembly: 1
# decorator: 1
# mambaforge: 1
# buffer-overflow: 1
# cmsis: 1
# paddleocr: 1
# css: 1
# wget: 1
# pythonanywhere: 1
# glob: 1
# spacy-3: 1
# non-linear-regression: 1
# apache-spark: 1
# gis: 1
# tsconfig: 1
# select: 1
# where-clause: 1
# grpc-java: 1
# activation: 1
# imagedata: 1
# tflearn: 1
# quantile-regression: 1
# farsi: 1
# post-processing: 1
# stellargraph: 1
# azure-web-app-service: 1
# azure-webapps: 1
# tf-slim: 1
# arduino-esp32: 1
# hpc: 1
# gdal: 1
# bitmap: 1
# rosetta: 1
# custom-function: 1
# parsing: 1
# pepper: 1
# boto3: 1
# alias: 1
# distilbert: 1
# medical: 1
# sanic: 1
# translation: 1
# quantum-computing: 1
# tensorflow-quantum: 1
# cirq: 1
# joi: 1
# custom-operator: 1
# eigen: 1
# coqui: 1
# autoregressive-models: 1
# html5-video: 1
# localhost: 1
# false-positive: 1
# qsub: 1
# return-value: 1
# vite: 1
# resampling: 1
# gstreamer: 1
# video-capture: 1
# johnsnowlabs-spark-nlp: 1
# rasa-sdk: 1
# segformer: 1
# logits: 1
# gdb: 1
# cuda-gdb: 1
# multicollinearity: 1
# paramiko: 1
# bitwise-xor: 1
# xgboost: 1
# numerical-integration: 1
# google-cloud-ai-platform-pipelines: 1
# sudo: 1
# p5.js: 1
# cppflow: 1
# pack: 1
# tensorflow-gradient: 1
# bitbake: 1
# powerpc: 1
# multiple-gpu: 1
# ros: 1
# pearson-correlation: 1
# pypi: 1
# partition: 1
# canvas: 1
# malloc: 1
# cmusphinx: 1
# ordereddict: 1
# dask-distributed: 1
# text-to-speech: 1
# gesture-recognition: 1
# logfile: 1
# numeric: 1
# categorical-data: 1
# while-loop: 1
# webcam: 1
# federated: 1
# chainer: 1
# content-security-policy: 1
# popart: 1
# poplar: 1
# sumo: 1
# google-cloud-build: 1
# reflection: 1
# xcode: 1
# core-audio: 1
# google-prediction: 1
# hidden-files: 1
# angularjs: 1
# ionic-framework: 1
# colormap: 1
# google-text-to-speech: 1
# speech-synthesis: 1
# button: 1
# display: 1
# mount: 1
# real-time: 1
# seed: 1
# virtual: 1
# web-applications: 1
# lookup-tables: 1
# netlify: 1
# debian: 1
# datetime: 1
# ajax: 1
# notimplementedexception: 1
# scala: 1
# circe: 1
# serve: 1
# hex: 1
# google-cloud-bigtable: 1
# cross-compiling: 1
# riscv: 1
# vuejs2: 1
# image-masking: 1
# ml-studio: 1
# binary-image: 1
# pybind11: 1
# motion: 1
# google-kubernetes-engine: 1
# pose: 1
# feed-forward: 1
# pthreads: 1
# cuda-context: 1
# multi-process-service: 1
# voxel: 1
# decode: 1
# react-native-vision-camera: 1
# uwsgi: 1
# model-viewer: 1
# porting: 1
# montecarlo: 1
# nonlinear-optimization: 1
# stan: 1
# hierarchical-bayesian: 1
# remote-debugging: 1
# environment-modules: 1
# apache-beam-io: 1
# sigkill: 1
# trax: 1
# spectrogram: 1
# physics: 1
# velocity: 1
# calibration: 1
# xamarin: 1
# microsoft-custom-vision: 1
# lda: 1
# topic-modeling: 1
# zlib: 1
# intel-tensorflow: 1
# web: 1
# execution: 1
# python-idle: 1
# point-clouds: 1
# tensorflow-extended: 1
# standardization: 1
# kivy: 1
# kivy-language: 1
# data-retrieval: 1
# embedding-lookup: 1
# group-by: 1
# hashmap: 1
# cryptography: 1
# tf.dataset: 1
# qt: 1
# bytecode: 1
# orientation: 1
# supervised-learning: 1
# estimation: 1
# conditional-formatting: 1
# bit-manipulation: 1
# sdk: 1
# permutation: 1
# sampled-softmax: 1
# keil: 1
# key: 1
# jq: 1
# emscripten: 1
# jquery: 1
# ddpg: 1
# ide: 1
# densevariational: 1
# python-decorators: 1
# go: 1
# buf: 1
# path: 1
# 7zip: 1
# xcopy: 1
# curve-fitting: 1
# set: 1
# compatibility: 1
# colors: 1
# image-annotations: 1
# hardware: 1
# interrupt: 1
# reduce: 1
# io: 1
# non-maximum-suppression: 1
# prefetch: 1
# probability-density: 1
# xla: 1
# counting: 1
# rank: 1
# find-occurrences: 1
# computer-science: 1
# color-space: 1
# hash: 1
# azure-functions: 1
# gcs: 1
# multiplexing: 1
# cvat: 1
# surface: 1
# ruby-on-rails: 1
# variable-assignment: 1
# compiler-optimization: 1
# k-means: 1
# conceptual: 1
# standard-deviation: 1
# nls: 1
# scipy-optimize: 1
# nonetype: 1
# replit: 1
# intellisense: 1
# subclassing: 1
# fbjs: 1
# np: 1
# unity-game-engine: 1
# collaborative-filtering: 1
# sparsecategoricalcrossentropy: 1
# pattern-recognition: 1
# generative-art: 1
# windows-11: 1
# difference: 1
# intellij-idea: 1
# filtering: 1
# uncertainty: 1
# opencl: 1
# google-publisher-tag: 1
# gpt-3: 1
# multiprocess: 1
# cpu-cores: 1
# nameerror: 1
# rbm: 1
# python-poetry: 1
# memory-profiling: 1
# internal-server-error: 1
# clang: 1
# amd-rocm: 1
# mmap: 1
# chatgpt-api: 1
# facenet: 1
# six: 1
# duplicates: 1
# unique: 1
# asgi: 1
# caffe2: 1
# python-typing: 1
# openmp: 1
# deprecated: 1
# ptx: 1
# export: 1
# symbol-not-found: 1
# python-2.6: 1
# utf-8: 1
# utf: 1
# automatic-mixed-precision: 1
# disable: 1
# ssl: 1
# bayesian-networks: 1
# pgmpy: 1
# object-tracking: 1
# python-logging: 1
# data-conversion: 1
# edges: 1
# torchhub: 1
# gaussianblur: 1
# eval: 1
# undirected-graph: 1
# super: 1
# mongodb: 1
# min: 1
# sign: 1
# absolute-value: 1
# batch-file: 1
# top-n: 1
# arguments: 1
# scope: 1
# ffmpeg: 1
# monk: 1
# image-formats: 1
# fortran: 1
# lightening: 1
# verbosity: 1
# motion-blur: 1
# unified-memory: 1
# lazy-evaluation: 1
# constructor: 1
# adversarial-attack: 1
# pairwise: 1
# fb-hydra: 1
# shared-memory: 1
# stateless: 1
# phash: 1
# imagehash: 1
# seek: 1
# nvlink: 1
# viewmodel-savedstate: 1
# python-imageio: 1
# batchnorm: 1
# cross-correlation: 1
# inverse: 1
# bias-neuron: 1
# linker-errors: 1
# satellite-image: 1
# yolov7: 1
# http: 1
# google-vision: 1
# tsne: 1
# numpy-memmap: 1
# registration: 1
# terminology: 1
# 2d: 1
# python-sockets: 1
# interceptor: 1
# detach: 1
# rotation: 1
# progress: 1
# diagonal: 1
# volatile: 1
# qr-code: 1
# illegalaccessexception: 1
# racing: 1
# fork: 1
# nvidia-smi: 1
# vram: 1
# numpy-indexing: 1
# cmd: 1
# broken-pipe: 1
# pyro.ai: 1
# gpu-shared-memory: 1
# layout-parser: 1
# simplex: 1
# datalore: 1
# multitasking: 1
# compression: 1
# memory-efficient: 1
# gaussian-mixture-model: 1
# cat: 1
# rms: 1
# spacy-transformers: 1
# fiftyone: 1
# alignment: 1
# pygad: 1
# selection: 1
# pipenv: 1
# scipy-optimize-minimize: 1
# docker-build: 1
# clip: 1
# contour: 1
# download: 1
# amazon-elastic-beanstalk: 1
# dlib: 1
# cartesian-product: 1
# endpoint: 1
# replace: 1
# image-compression: 1
# unfold: 1
# union: 1
# rgba: 1
# pytest: 1
# environment-variables: 1
# transpose: 1
# libraries: 1
# continuous-integration: 1
# continuous-deployment: 1
# mlops: 1
# binning: 1
# png: 1
# rendering: 1
# pybullet: 1
# differentiation: 1
# remote-server: 1
# static-quantization: 1
# reverse: 1
# isin: 1
# indices: 1
# minikube: 1
# kubeflow: 1
# adam: 1
# log-likelihood: 1
# pycaret: 1
# reward: 1
# overriding: 1
# finance: 1
# intel-python: 1
# airflow: 1
# pycocotools: 1
# azure-pipelines: 1
# uri: 1
# processing-efficiency: 1
# closures: 1
# svd: 1
# orthogonal: 1
# numerical-stability: 1
# dataparallel: 1
# stack: 1
# openai-clip: 1
# advanced-indexing: 1
# pytorch-datapipe: 1
# torchdata: 1
# expression: 1
# hyperbolic-function: 1
# bin: 1
# correlation: 1
# spatial-data: 1
# equivalence: 1
# einsum: 1
# django-models: 1
# setup.py: 1
# part-of-speech: 1
# neuraxle: 1
# mxnet: 1
# matrix-factorization: 1
# ram: 1
# python-importlib: 1
# scatter: 1
# dgl: 1
# pythonpath: 1
# cycle: 1
# intersection: 1
# diff: 1
# google-cloud-run: 1
# gradio: 1
# multihead-attention: 1
# robustness: 1
# time-complexity: 1
# flops: 1
# git: 1
# version-control: 1
# azureml-python-sdk: 1
# modelsummary: 1
# 3d: 1
# caffe: 1
# survival-analysis: 1
# computation: 1
# numerical-methods: 1
# shortcut: 1
# pairwise-distance: 1
# pysyft: 1
# python-sphinx: 1
# autodoc: 1
# printing: 1
# standard-error: 1
# intel-myriadx: 1
# cuda-streams: 1
# coding-style: 1
# conventions: 1
# digits: 1
# projection: 1
# average: 1
# polynomial-approximations: 1
# f#: 1
# diffsharp: 1
# algebra: 1
# checkpointing: 1
# buffer: 1
# iterable-unpacking: 1
# apache-kafka: 1
# perplexity: 1
# minimization: 1
# logical-operators: 1
# integer-partition: 1
# torchstudio: 1
# sample: 1
# feature-engineering: 1
# dnn9: 1
# multikey: 1
# equality: 1
# subtraction: 1
# definition: 1
# google-compute-engine: 1
# gabor-filter: 1
# flux: 1
# deep-fake: 1
# data-fitting: 1
# addition: 1
# covariance: 1
# web-deployment: 1
# few-shot-learning: 1
# learn2learn: 1
# file-read: 1
# kronecker-product: 1
# large-files: 1
# tabular: 1
# multi-level: 1
# ipython: 1
# contourf: 1
# kedro: 1
# refactoring: 1

# %%
# Give CSV for the Sorted Tag Counts
df = pd.DataFrame(sorted_counts, columns=['Tag', 'Count'])
df.to_csv('../Dataset/Tag_Counts.csv', index=False)

# %% [markdown]
# ## Taxonomy
#
# * Model
#     * Missing/Redundant/Wrong Layer
#     * Layer Properties
#     * Activation Function
# * Tensor & Inputs
#     * Wrong Tensor Shape
#     * Wrong Input
# * Training
#     * Hyperparameters
#     * Loss Function
#     * Preprocessing of Training Data
#     * Optimiser
#     * Training Data Quality
#     * Training Process
# * GPU
# * API

# %% [markdown]
# ### Types of Networks covered
#
# * Convolutional Neural Network (CNN): 480
# * Long Short-Term Memory (LSTM): 201
# * Recurrent Neural Network (RNN): 92
# * Generative Adversarial Network (GAN): 56
# * Autoencoder: 75
# * Siamese Network: 9
# * Graph Neural Network (GNN): 5
# * Multilayer Perceptron (MLP): 11
# * Self-Attention: 3

# %% [markdown]
# ### Relevant Tags for Different Types of Bugs
#
# * Tensor: 391
# * NumPy: 366
# * GPU: 157
# * Loss Function: 97
# * Dataset: 77
# * Arrays: 60
# * Training Data: 49
# * NVIDIA: 44
# * CUDA: 43
# * Optimization: 39
# * Cross Entropy: 36
# * Backpropogation: 33
# * Model: 30
# * Gradient: 30
# * Data Augmentation: 25
# * Loss: 25
# * Reshape: 23
# * Activation Function: 19
# * Performance: 18
# * Dropout: 17
# * Type Error: 14
# * Runtime Error: 13
# * Layer: 13
# * Memory: 13
# * Out of Memory: 12
# * Normalization: 12
# * Dimensions: 10
# * Learning Rate: 9
# * CPU: 7
# * NaN: 7
# * Memory Leaks: 6
# * Hyperparameters: 5
# * Segmentation Fault: 5
# * Initialization: 5
# * Imbalanced Data: 3

# %% [markdown]
# ### Bugs and their Tags
#
# Model: Gradient, Layer, Model, Activation Function
#
# Tensor & Input: Tensor
#
# Training: Loss Function, Training Data, Optimization, Cross Entropy, Backpropagation, Loss, Data Augmentation, Performance, Dropout, Learning Rate, Hyperparameters, Initialization, Imbalanced Data, Runtime Error, Segmentation Fault, NaN
#
# GPU: GPU, NVIDIA, CUDA, Out of Memory, Memory Leaks
#
# API: Type Error, Value Error, Attribute Error, Import Error, Compiler Error, Syntax Error, Module Not Found Error

# %%
keras = pd.read_csv('../Dataset/Keras_Posts.csv')
tensorflow = pd.read_csv('../Dataset/Tensorflow_Posts.csv')
pytorch = pd.read_csv('../Dataset/Pytorch_Posts.csv')

# Merge these dataframes
df = pd.concat([keras, tensorflow, pytorch], ignore_index=True)

# Remove <> from the tags
df['Spaced_Tags'] = df['Tags'].str.replace(r'<', ' ')
df['Spaced_Tags'] = df['Tags'].str.replace(r'>', ' ')

# Drop Unnamed: 3 column and rename Unnamed: 0 to links
df.drop(['Unnamed: 3'], axis=1, inplace=True)
df.rename(columns={'Unnamed: 0': 'Links'}, inplace=True)

# %%
# Create a new column ID
df['Id'] = df.index
for index, row in df.iterrows():
    df.at[index, 'Id'] = df.at[index, 'Links'].split('/')[-1]

# %%
def get_posts(tags, df):
    condition = False
    for tag in tags:
        condition = condition | df['Spaced_Tags'].str.contains(r'\b{}\b'.format(tag))
    return df[condition]

model_bugs = get_posts(['layer', 'model', 'activation-function'], df)
tensor_bugs = get_posts(['tensor'], df)
training_bugs = get_posts(['loss-function', 'training-data', 'optimization', 'loss', 'data-augmentation', 'performance', 'learning-rate', 'hyperparameters', 'initialization', 'imbalanced-data', 'nan'], df)
gpu_bugs = get_posts(['gpu', 'nvidia', 'cuda'], df)
api_bugs = get_posts(['typeerror', 'valueerror', 'attributeerror', 'importerror', 'compilererrors', 'syntaxerror', 'modulenotfounderror'], df)

# %%
print (f'Number of Model Bugs: {len(model_bugs)}')
print (f'Number of Tensor & Input Bugs: {len(tensor_bugs)}')
print (f'Number of Training Bugs: {len(training_bugs)}')
print (f'Number of GPU Bugs: {len(gpu_bugs)}')
print (f'Number of API Bugs: {len(api_bugs)}')
# Out:
# Number of Model Bugs: 280
# Number of Tensor & Input Bugs: 391
# Number of Training Bugs: 274
# Number of GPU Bugs: 239
# Number of API Bugs: 58

# %%
# Common posts between model_bugs and tensor_input
model_tensor = pd.merge(model_bugs, tensor_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between model_bugs and training_bugs
model_training = pd.merge(model_bugs, training_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between model_bugs and gpu_bugs
model_gpu = pd.merge(model_bugs, gpu_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between model_bugs and api_bugs
model_api = pd.merge(model_bugs, api_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between tensor_bugs and training_bugs
tensor_training = pd.merge(tensor_bugs, training_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between tensor_bugs and gpu_bugs
tensor_gpu = pd.merge(tensor_bugs, gpu_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between tensor_bugs and api_bugs
tensor_api = pd.merge(tensor_bugs, api_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between training_bugs and gpu_bugs
training_gpu = pd.merge(training_bugs, gpu_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between training_bugs and api_bugs
training_api = pd.merge(training_bugs, api_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

# Common posts between gpu_bugs and api_bugs
gpu_api = pd.merge(gpu_bugs, api_bugs, how='inner', on=['Id', 'Links', 'Title', 'Tags', 'Spaced_Tags'])

print (f'Number of Common Posts between Model & Tensor: {len(model_tensor)}')
print (f'Number of Common Posts between Model & Training: {len(model_training)}')
print (f'Number of Common Posts between Model & GPU: {len(model_gpu)}')
print (f'Number of Common Posts between Model & API: {len(model_api)}')
print (f'Number of Common Posts between Tensor & Training: {len(tensor_training)}')
print (f'Number of Common Posts between Tensor & GPU: {len(tensor_gpu)}')
print (f'Number of Common Posts between Tensor & API: {len(tensor_api)}')
print (f'Number of Common Posts between Training & GPU: {len(training_gpu)}')
print (f'Number of Common Posts between Training & API: {len(training_api)}')
print (f'Number of Common Posts between GPU & API: {len(gpu_api)}')
# Out:
# Number of Common Posts between Model & Tensor: 7
# Number of Common Posts between Model & Training: 14
# Number of Common Posts between Model & GPU: 2
# Number of Common Posts between Model & API: 1
# Number of Common Posts between Tensor & Training: 8
# Number of Common Posts between Tensor & GPU: 9
# Number of Common Posts between Tensor & API: 0
# Number of Common Posts between Training & GPU: 3
# Number of Common Posts between Training & API: 3
# Number of Common Posts between GPU & API: 0

# %%
# Merge all the dataframes
df = pd.concat([model_bugs, tensor_bugs, training_bugs, gpu_bugs, api_bugs], ignore_index=True)
df.drop_duplicates(subset=['Id'], keep=False, inplace=True)

# %%
model_bugs = get_posts(['layer', 'model', 'activation-function'], df)
tensor_bugs = get_posts(['tensor'], df)
training_bugs = get_posts(['loss-function', 'training-data', 'optimization', 'loss', 'data-augmentation', 'performance', 'learning-rate', 'hyperparameters', 'initialization', 'imbalanced-data', 'nan'], df)
gpu_bugs = get_posts(['gpu', 'nvidia', 'cuda'], df)
api_bugs = get_posts(['typeerror', 'valueerror', 'attributeerror', 'importerror', 'compilererrors', 'syntaxerror', 'modulenotfounderror'], df)

# %%
print (f'Number of Unique Model Bugs: {len(model_bugs)}')
print (f'Number of Unique Tensor & Input Bugs: {len(tensor_bugs)}')
print (f'Number of Unique Training Bugs: {len(training_bugs)}')
print (f'Number of Unique GPU Bugs: {len(gpu_bugs)}')
print (f'Number of Unique API Bugs: {len(api_bugs)}')
# Out:
# Number of Unique Model Bugs: 258
# Number of Unique Tensor & Input Bugs: 369
# Number of Unique Training Bugs: 248
# Number of Unique GPU Bugs: 225
# Number of Unique API Bugs: 54

# %%
total_len = len(model_bugs) + len(tensor_bugs) + len(training_bugs) + len(gpu_bugs) + len(api_bugs)
print (f'Total Number of Unique Bugs: {total_len}')
print (f'Percentage of Model Bugs: {round((len(model_bugs)/total_len)*100, 2)}%')
print (f'Percentage of Tensor & Input Bugs: {round((len(tensor_bugs)/total_len)*100, 2)}%')
print (f'Percentage of Training Bugs: {round((len(training_bugs)/total_len)*100, 2)}%')
print (f'Percentage of GPU Bugs: {round((len(gpu_bugs)/total_len)*100, 2)}%')
print (f'Percentage of API Bugs: {round((len(api_bugs)/total_len)*100, 2)}%')
# Out:
# Total Number of Unique Bugs: 1154
# Percentage of Model Bugs: 22.36%
# Percentage of Tensor & Input Bugs: 31.98%
# Percentage of Training Bugs: 21.49%
# Percentage of GPU Bugs: 19.5%
# Percentage of API Bugs: 4.68%

# %%
# Total: 250 Bugs, derive  number of model bugs, tensor bugs, training bugs and gpu bugs, and api bugs
model_bugs = model_bugs.sample(n=56, random_state=42)
tensor_bugs = tensor_bugs.sample(n=80, random_state=42)
training_bugs = training_bugs.sample(n=54, random_state=42)
gpu_bugs = gpu_bugs.sample(n=49, random_state=42)
api_bugs = api_bugs.sample(n=12, random_state=42)

model_bugs['Type'] = 'model'
tensor_bugs['Type'] = 'tensor'
training_bugs['Type'] = 'training'
gpu_bugs['Type'] = 'gpu'
api_bugs['Type'] = 'api'

# Merge all the dataframes
df = pd.concat([model_bugs, tensor_bugs, training_bugs, gpu_bugs, api_bugs], ignore_index=True)
df = df.drop(['Spaced_Tags'], axis=1)

# %%
# Extract tags and count occurrences
tags = [re.findall(r'<([^>]*)>', tag) for tag in df['Tags']]
tag_counts = Counter([tag for sublist in tags for tag in sublist])

# Sort tag counts in descending order
sorted_counts = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

# Print sorted tag counts
for tag, count in sorted_counts:
    print(f"{tag}: {count}")
# Out:
# python: 146
# pytorch: 144
# tensor: 80
# tensorflow: 68
# gpu: 32
# keras: 29
# deep-learning: 27
# machine-learning: 24
# loss-function: 20
# neural-network: 17
# bert-language-model: 17
# conv-neural-network: 13
# huggingface-transformers: 11
# nvidia: 11
# nlp: 10
# loss: 10
# training-data: 10
# python-3.x: 9
# numpy: 9
# cuda: 9
# torch: 8
# transformer-model: 7
# tensorflow2.0: 7
# attention-model: 6
# keras-layer: 6
# lstm: 6
# pre-trained-model: 6
# tensorflow-model-garden: 5
# google-colaboratory: 5
# optimization: 5
# activation-function: 4
# autoencoder: 4
# c++: 4
# pytorch-lightning: 4
# mse: 4
# attributeerror: 4
# typeerror: 4
# relu: 3
# matrix: 3
# language-model: 3
# word-embedding: 3
# tf.keras: 3
# tensorflow-datasets: 3
# tensorflow.js: 3
# memory: 3
# pytorch-dataloader: 3
# computer-vision: 3
# data-augmentation: 3
# performance: 3
# ubuntu: 3
# valueerror: 3
# multiclass-classification: 2
# normalization: 2
# model: 2
# text-classification: 2
# classification: 2
# embedding: 2
# layer: 2
# torchscript: 2
# gpt-2: 2
# scikit-learn: 2
# javascript: 2
# generative-adversarial-network: 2
# slice: 2
# indexing: 2
# backpropagation: 2
# pandas: 2
# learning-rate: 2
# jupyter-notebook: 2
# object-detection: 2
# cudnn: 2
# dataloader: 2
# windows: 2
# mixture-model: 1
# multi-layer: 1
# load: 1
# tensorflow-hub: 1
# roberta-language-model: 1
# huggingface-tokenizers: 1
# parameters: 1
# dropout: 1
# sequence-to-sequence: 1
# tensorflow-lite: 1
# protocol-buffers: 1
# siamese-network: 1
# distributed-computing: 1
# hook: 1
# self-attention: 1
# sentiment-analysis: 1
# fine-tune: 1
# model-fitting: 1
# jax: 1
# tensorflow-data-validation: 1
# deeplab: 1
# machine-translation: 1
# matrix-multiplication: 1
# confusion-matrix: 1
# vectorization: 1
# node.js: 1
# arrays: 1
# runtime-error: 1
# react-native: 1
# precision: 1
# unfold: 1
# numpy-slicing: 1
# syntax: 1
# zero-padding: 1
# indices: 1
# loops: 1
# iteration: 1
# broadcast: 1
# reshape: 1
# dataframe: 1
# random: 1
# rounding: 1
# ragged-tensors: 1
# multidimensional-array: 1
# clip: 1
# reduce: 1
# tensorflow2.x: 1
# tensordot: 1
# python-imaging-library: 1
# diagonal: 1
# metrics: 1
# tensorboard: 1
# hyperparameters: 1
# initialization: 1
# runtime: 1
# image-segmentation: 1
# torchvision: 1
# artificial-intelligence: 1
# scipy: 1
# softmax: 1
# image-processing: 1
# gradient: 1
# custom-training: 1
# closures: 1
# nan: 1
# autograd: 1
# r: 1
# missing-data: 1
# syntax-error: 1
# overfitting-underfitting: 1
# batchsize: 1
# tqdm: 1
# function: 1
# methods: 1
# intel: 1
# intel-python: 1
# intel-pytorch: 1
# dnn9: 1
# mathematical-optimization: 1
# validation: 1
# plot: 1
# mean-square-error: 1
# mobilenet: 1
# automatic-differentiation: 1
# distributed-training: 1
# adversarial-machines: 1
# conda: 1
# nvidia-jetson: 1
# mini-forge: 1
# out-of-memory: 1
# asynchronous: 1
# amazon-web-services: 1
# partition: 1
# dtype: 1
# time-series: 1
# u8darts: 1
# libtorch: 1
# cmake: 1
# debugging: 1
# apex: 1
# cpu: 1
# macos: 1
# cuda-context: 1
# multi-process-service: 1
# tfx: 1
# tritonserver: 1
# gpgpu: 1
# visual-studio-code: 1
# ssh: 1
# paramiko: 1
# pytorch-geometric: 1
# multiprocessing: 1
# nvcc: 1
# docker: 1
# docker-compose: 1
# nvidia-docker: 1
# anaconda: 1
# exit-code: 1
# multi-gpu: 1
# ddp: 1
# pip: 1
# amazon-sagemaker: 1
# tpu: 1
# dataparallel: 1
# installation: 1
# miniconda: 1
# nvidia-smi: 1
# vram: 1
# wsl-2: 1
# cuda-streams: 1
# size: 1
# keyerror: 1
# tensorflow-federated: 1
# pycharm: 1
# windows-10: 1
# importerror: 1

# %%
df.head()
# Out:
#                                           Links  \
# 0  https://stackoverflow.com/questions/65918888
# 1  https://stackoverflow.com/questions/63478947
# 2  https://stackoverflow.com/questions/67356013
# 3  https://stackoverflow.com/questions/65228352
# 4  https://stackoverflow.com/questions/72489570
#
#                                                Title  \
# 0  Mixture parameters from a TensorFlow Probabili...
# 1  Correct Way to Fine-Tune/Train HuggingFace's M...
# 2  Multiple Activation Functions for multiple Lay...
# 3  Matrix inverse approximation with keras dense ...
# 4  Getting random output every time on running Ne...
#
#                                                 Tags        Id   Type
# 0  <python><tensorflow><neural-network><mixture-m...  65918888  model
# 1  <python><pytorch><bert-language-model><hugging...  63478947  model
# 2  <tensorflow><neural-network><multiclass-classi...  67356013  model
# 3  <python><matrix><keras><neural-network><multi-...  65228352  model
# 4  <nlp><pytorch><huggingface-transformers><bert-...  72489570  model

# %%
df.to_csv('../Dataset/DL_Bugs.csv', index=False)
